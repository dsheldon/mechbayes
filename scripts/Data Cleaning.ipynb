# %%
import pandas as pd
import mechbayes.util as util
import matplotlib.pyplot as plt
import numpy as onp
import data_cleaning

# %%
data = util.load_data()

place = 'OK'
var = 'death'
start = '2021-06-15'

#forecast_date = data['US']['data'].index[-1]
forecast_date = '2021-08-08'

data_cleaning.clean(data, forecast_date)


data[place]['data'].loc[start:forecast_date, var].plot(style='-o')
plt.title(place)
plt.show()

data[place]['data'].loc[start:forecast_date, var].diff().plot(style='-o')
print(data[place]['data'].loc[start:forecast_date, var])
print(data[place]['data'].loc[start:forecast_date, var].diff())
# Out:
# /Users/sheldon/projects/mechbayes/mechbayes/util.py:220: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/sheldon/projects/mechbayes/mechbayes/util.py:230: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ************************************************************
# 2021-06-15    7350.0
# 2021-06-16    7354.0
# 2021-06-17    7359.0
# 2021-06-18    7363.0
# 2021-06-19    7367.0
# 2021-06-20    7372.0
# 2021-06-21    7376.0
# 2021-06-22    7380.0
# 2021-06-23    7384.0
# 2021-06-24    7385.0
# 2021-06-25    7385.0
# 2021-06-26    7386.0
# 2021-06-27    7387.0
# 2021-06-28    7387.0
# 2021-06-29    7387.0
# ...
